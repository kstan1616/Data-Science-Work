# %%
import pandas as pd

draft = pd.read_csv('draft78.csv')

draft
# Out:
#       Pick                  Player   Yrs  Draft
# 0        1         Mychal Thompson  12.0   1978
# 1        2               Phil Ford   7.0   1978
# 2        3              Rick Robey   8.0   1978
# 3        4  Micheal Ray Richardson   8.0   1978
# 4        5            Purvis Short  12.0   1978
# 5        6              Larry Bird  13.0   1978
# 6        7              Ron Brewer   8.0   1978
# 7        8        Freeman Williams   6.0   1978
# 8        9            Reggie Theus  13.0   1978
# 9       10               Butch Lee   2.0   1978
# 10      11             James Hardy   4.0   1978
# 11      12          George Johnson   8.0   1978
# 12      13          Winford Boynes   3.0   1978
# 13      14           Roger Phegley   6.0   1978
# 14      15           Mike Mitchell  10.0   1978
# 15      16             Jack Givens   2.0   1978
# 16      17             Rod Griffin   NaN   1978
# 17      18            Dave Corzine  13.0   1978
# 18      19            Marty Byrnes   4.0   1978
# ...

# %%
season = pd.read_csv('season78.csv')

season
# Out:
#        Season               Player    WS
# 0        1979          Aaron James   1.7
# 1        1979      Adrian Dantley*   5.7
# 2        1979           Al Skinner   1.2
# 3        1979        Alex English*   7.0
# 4        1979        Allan Bristow   3.5
# 5        1979       Alonzo Bradley   0.1
# 6        1979          Alvan Adams   7.6
# 7        1979          Alvin Scott   4.4
# 8        1979      Andre Wakefield  -0.9
# 9        1979      Anthony Roberts   1.7
# 10       1979          Armond Hill   4.2
# 11       1979       Artis Gilmore*  12.7
# 12       1979          Austin Carr   5.0
# 13       1979       Bayard Forrest   1.2
# 14       1979         Ben Poquette   2.5
# 15       1979        Bernard King*   6.5
# 16       1979       Bill Robinzine   6.9
# 17       1979         Billy Knight   3.7
# 18       1979       Billy McKinney   3.0
# 19       1979         Billy Paultz   5.1
# 20       1979          Bingo Smith   2.1
# 21       1979             Bo Ellis   0.5
# ...
